# %% [markdown]
# <a href="https://colab.research.google.com/github/CallMeIsEthan/TriTueNhanTao/blob/main/Minimax_AlphaBeta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><b>BÁO CÁO MÔN HỌC</b></p>
# <p>Chủ đề: Thuật toán tìm kiếm đối kháng</p>

# %%
import copy
import math
import random
import numpy

# %%
X = "X"
O = "O"
EMPTY = None
user = None
ai = None

# %%
def initial_state():
  return [[EMPTY, EMPTY, EMPTY],
          [EMPTY, EMPTY, EMPTY],
          [EMPTY, EMPTY, EMPTY]]

# %%
def player(board):
  count = 0
  for i in board:
    for j in i:
      if j:
        count += i
  if count % 2 != 0:
    return ai
  return user
